# %%
from google.colab import drive
drive.mount('/content/drive/')

# !pip install -r /content/drive/MyDrive/project/semantic-segmentation-roads/eomt/requirements.txt
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ...

# %%
# %cd /content/drive/MyDrive/project/semantic-segmentation-roads/eomt
# Out:
# /content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eomt

# %%
import torch

ckpt_path = "/content/drive/MyDrive/project/checkpoints/4_components_20ep/last.ckpt"

ckpt = torch.load(
    ckpt_path,
    weights_only=False
)

state_dict = ckpt["state_dict"]


out_path = "/content/drive/MyDrive/project/eomt_coco_finetuned.bin"

torch.save(state_dict, out_path)

print("Salvati solo i pesi CPU-safe in:", out_path)
print("Numero tensori:", len(state_dict))
print("Prime chiavi:")
for k in list(state_dict.keys())[:20]:
    print(k)
# Out:
# Salvati solo i pesi CPU-safe in: /content/drive/MyDrive/project/eomt_coco_finetuned.bin
# Numero tensori: 198
# Prime chiavi:
# network.attn_mask_probs
# network.encoder.pixel_mean
# network.encoder.pixel_std
# network.encoder.backbone.cls_token
# network.encoder.backbone.reg_token
# network.encoder.backbone.pos_embed
# network.encoder.backbone.patch_embed.proj.weight
# network.encoder.backbone.patch_embed.proj.bias
# network.encoder.backbone.blocks.0.norm1.weight
# network.encoder.backbone.blocks.0.norm1.bias
# network.encoder.backbone.blocks.0.attn.qkv.weight
# network.encoder.backbone.blocks.0.attn.qkv.bias
# network.encoder.backbone.blocks.0.attn.proj.weight
# network.encoder.backbone.blocks.0.attn.proj.bias
# network.encoder.backbone.blocks.0.ls1.gamma
# network.encoder.backbone.blocks.0.norm2.weight
# network.encoder.backbone.blocks.0.norm2.bias
# network.encoder.backbone.blocks.0.mlp.fc1.weight
# network.encoder.backbone.blocks.0.mlp.fc1.bias
# ...

# %%
# %cd /content/drive/MyDrive/project/semantic-segmentation-roads/eval
# Out:
# /content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eval

# %%
! python evalAnomalyEOMT.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model 'coco_finetuned'
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eval/evalAnomalyEOMT.py", line 14, in <module>
#     import torch
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 409, in <module>
#     from torch._C import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 463, in _lock_unlock_module
# KeyboardInterrupt
# ^C

# %%
! python evalAnomalyEOMT.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model 'coco_finetuned'
# Out:
# 2026-05-27 14:16:21.223311: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/eomt_coco_finetuned.bin
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: FS_LostFound_full
# ...
#   [100/100] Elaborando 91.png...
#  -> MSP        | AUPRC: 32.14% | FPR@TPR95: 27.32%
#  -> MAXLOGIT   | AUPRC: 32.25% | FPR@TPR95: 27.80%
#  -> MAXENTROPY | AUPRC: 33.04% | FPR@TPR95: 26.73%
# ...

# %%
! python evalAnomalyEOMT_scaling.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset"
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 143MB/s]
# 2026-05-27 15:32:16.772445: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/eomt_cityscapes.bin
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: FS_LostFound_full
# ...
#   [100/100] Elaborando 91.png...
#  -> MSP        | AUPRC: 16.39% | FPR@TPR95: 13.01%
#  -> MAXLOGIT   | AUPRC: 16.38% | FPR@TPR95: 12.78%
# ...
