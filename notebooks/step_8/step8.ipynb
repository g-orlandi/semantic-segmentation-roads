# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/project/semantic-segmentation-roads/eomt/requirements.txt

# %%
# %cd /content/drive/MyDrive/project/semantic-segmentation-roads/eval
# Out:
# /content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eval

# %%
! python evalAnomalyEOMT.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model "coco"
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 173MB/s]
# 2026-05-30 14:09:37.616981: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/models_weights/eomt_coco.bin
# Missing keys: []
# Unexpected keys: []
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: FS_LostFound_full
# ...
#   [100/100] Elaborando 91.png...
#  -> MSP        | AUPRC: 11.10% | FPR@TPR95: 89.68%
# ...

# %%
! python evalAnomalyEOMT.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model 'coco_finetuned'
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 153MB/s]
# 2026-05-31 00:59:50.212300: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/models_weights/eomt_coco_finetuned.bin
# Missing keys: []
# Unexpected keys: []
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: RoadAnomaly
# ...
#   [60/60] Elaborando 46.jpg...
#  -> MSP        | AUPRC: 51.31% | FPR@TPR95: 29.71%
# ...
