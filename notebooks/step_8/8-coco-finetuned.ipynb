# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/project/semantic-segmentation-roads/eomt/requirements.txt

# %%
# %cd /content/drive/MyDrive/project/semantic-segmentation-roads/eomt
# Out:
# /content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eomt

# %%
import torch

ckpt_path = "/content/drive/MyDrive/project/checkpoints/4_components_20ep/best-epoch=05.ckpt"

ckpt = torch.load(
    ckpt_path,
    weights_only=False
)

state_dict = ckpt["state_dict"]


out_path = "/content/drive/MyDrive/project/models_weights/eomt_coco_finetuned.bin"

torch.save(state_dict, out_path)

print("Salvati solo i pesi CPU-safe in:", out_path)
print("Numero tensori:", len(state_dict))
print("Prime chiavi:")
for k in list(state_dict.keys())[:20]:
    print(k)
# Out:
# Salvati solo i pesi CPU-safe in: /content/drive/MyDrive/project/models_weights/eomt_coco_finetuned.bin
# Numero tensori: 198
# Prime chiavi:
# network.attn_mask_probs
# network.encoder.pixel_mean
# network.encoder.pixel_std
# network.encoder.backbone.cls_token
# network.encoder.backbone.reg_token
# network.encoder.backbone.pos_embed
# network.encoder.backbone.patch_embed.proj.weight
# network.encoder.backbone.patch_embed.proj.bias
# network.encoder.backbone.blocks.0.norm1.weight
# network.encoder.backbone.blocks.0.norm1.bias
# network.encoder.backbone.blocks.0.attn.qkv.weight
# network.encoder.backbone.blocks.0.attn.qkv.bias
# network.encoder.backbone.blocks.0.attn.proj.weight
# network.encoder.backbone.blocks.0.attn.proj.bias
# network.encoder.backbone.blocks.0.ls1.gamma
# network.encoder.backbone.blocks.0.norm2.weight
# network.encoder.backbone.blocks.0.norm2.bias
# network.encoder.backbone.blocks.0.mlp.fc1.weight
# network.encoder.backbone.blocks.0.mlp.fc1.bias
# ...

# %%
import torch

ckpt_path = "/content/drive/MyDrive/project/checkpoints/3_components_20ep/best-epoch=09.ckpt"

ckpt = torch.load(
    ckpt_path,
    weights_only=False
)

state_dict = ckpt["state_dict"]


out_path = "/content/drive/MyDrive/project/models_weights/3comp_eomt_coco_finetuned.bin"

torch.save(state_dict, out_path)

print("Salvati solo i pesi CPU-safe in:", out_path)
print("Numero tensori:", len(state_dict))
print("Prime chiavi:")
for k in list(state_dict.keys())[:20]:
    print(k)
# Out:
# Salvati solo i pesi CPU-safe in: /content/drive/MyDrive/project/models_weights/3comp_eomt_coco_finetuned.bin
# Numero tensori: 198
# Prime chiavi:
# network.attn_mask_probs
# network.encoder.pixel_mean
# network.encoder.pixel_std
# network.encoder.backbone.cls_token
# network.encoder.backbone.reg_token
# network.encoder.backbone.pos_embed
# network.encoder.backbone.patch_embed.proj.weight
# network.encoder.backbone.patch_embed.proj.bias
# network.encoder.backbone.blocks.0.norm1.weight
# network.encoder.backbone.blocks.0.norm1.bias
# network.encoder.backbone.blocks.0.attn.qkv.weight
# network.encoder.backbone.blocks.0.attn.qkv.bias
# network.encoder.backbone.blocks.0.attn.proj.weight
# network.encoder.backbone.blocks.0.attn.proj.bias
# network.encoder.backbone.blocks.0.ls1.gamma
# network.encoder.backbone.blocks.0.norm2.weight
# network.encoder.backbone.blocks.0.norm2.bias
# network.encoder.backbone.blocks.0.mlp.fc1.weight
# network.encoder.backbone.blocks.0.mlp.fc1.bias
# ...

# %%
import torch

ckpt_path = "/content/drive/MyDrive/project/checkpoints/head_only_15ep_20260512_0633/best-epoch=09.ckpt"

ckpt = torch.load(
    ckpt_path,
    weights_only=False
)

state_dict = ckpt["state_dict"]


out_path = "/content/drive/MyDrive/project/models_weights/head_eomt_coco_finetuned.bin"

torch.save(state_dict, out_path)

print("Salvati solo i pesi CPU-safe in:", out_path)
print("Numero tensori:", len(state_dict))
print("Prime chiavi:")
for k in list(state_dict.keys())[:20]:
    print(k)
# Out:
# Salvati solo i pesi CPU-safe in: /content/drive/MyDrive/project/models_weights/head_eomt_coco_finetuned.bin
# Numero tensori: 198
# Prime chiavi:
# network.attn_mask_probs
# network.encoder.pixel_mean
# network.encoder.pixel_std
# network.encoder.backbone.cls_token
# network.encoder.backbone.reg_token
# network.encoder.backbone.pos_embed
# network.encoder.backbone.patch_embed.proj.weight
# network.encoder.backbone.patch_embed.proj.bias
# network.encoder.backbone.blocks.0.norm1.weight
# network.encoder.backbone.blocks.0.norm1.bias
# network.encoder.backbone.blocks.0.attn.qkv.weight
# network.encoder.backbone.blocks.0.attn.qkv.bias
# network.encoder.backbone.blocks.0.attn.proj.weight
# network.encoder.backbone.blocks.0.attn.proj.bias
# network.encoder.backbone.blocks.0.ls1.gamma
# network.encoder.backbone.blocks.0.norm2.weight
# network.encoder.backbone.blocks.0.norm2.bias
# network.encoder.backbone.blocks.0.mlp.fc1.weight
# network.encoder.backbone.blocks.0.mlp.fc1.bias
# ...

# %%
# %cd /content/drive/MyDrive/project/semantic-segmentation-roads/eval
# Out:
# /content/drive/.shortcut-targets-by-id/1kGi4cSNJjM14ClVvPXJ9VY70JDkofHGn/project/semantic-segmentation-roads/eval

# %%
# !python evalAnomalyEOMT_oom.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model 'coco_finetuned'
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 130MB/s]
# 2026-05-30 08:26:09.828805: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/models_weights/eomt_coco_finetuned.bin
# Missing keys: []
# Unexpected keys: []
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: FS_LostFound_full
# ...
#   [100/100] Elaborando 91.png...
#  -> MSP        | AUPRC: 69.63% | FPR@TPR95: 18.70%
# ...

# %%
# !python evalAnomalyEOMT_oom.py --base_dir "/content/drive/MyDrive/project/Anomaly_Validation_Datasets/Validation_Dataset" --model 'coco_finetuned'
# Out:
# 2026-05-30 00:26:31.894522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Caricamento pesi da: /content/drive/MyDrive/project/models_weights/eomt_coco_finetuned.bin
# Missing keys: []
# Unexpected keys: []
# Modello EoMT caricato con successo.
#
# ...
#  Inizio valutazione Dataset: FS_LostFound_full
# ...
#   [100/100] Elaborando 91.png...
# ^C
